# %%
import ibis
import ibis_baseline as ib

# %%
con = ibis.datafusion.connect()
df = con.read_csv('./example_phonebook_data.csv')

# %%
ib.count_by_email_provider(df=df)

# %%
ib.count_by_state(df=df)
