# %%
import duckdb
import duckdb_baseline as db

# %%
con = duckdb.connect()
df = con.read_csv('./example_phonebook_data.csv')

# %%
db.count_by_email_provider(df=df)
# Out:
# ┌─────────────────────┬───────┐
# │   email_provider    │ count │
# │       varchar       │ int64 │
# ├─────────────────────┼───────┤
# │ dummyemail.com      │    25 │
# │ otherdummyemail.com │    25 │
# └─────────────────────┴───────┘

# %%
db.count_by_state(df=df)
# Out:
# ┌────────────┬───────┐
# │   state    │ count │
# │  varchar   │ int64 │
# ├────────────┼───────┤
# │ California │    13 │
# │ Texas      │    13 │
# │ Florida    │    12 │
# │ New York   │    12 │
# └────────────┴───────┘

# %%
df.to_arrow_table()
# Out:
# pyarrow.Table
# first_name: string
# last_name: string
# phone_number: string
# state: string
# country: string
# email: string
# ----
# first_name: [["John","Emma","Michael","Sarah","John",...,"Emma","Michael","Sarah","John","Emma"]]
# last_name: [["Smith","Johnson","Williams","Brown","Jones",...,"Rivera","Campbell","Mitchell","Carter","Roberts"]]
# phone_number: [["555-0101","555-0102","555-0103","555-0104","555-0105",...,"555-0146","555-0147","555-0148","555-0149","555-0150"]]
# state: [["California","Texas","New York","Florida","California",...,"Texas","New York","Florida","California","Texas"]]
# country: [["USA","USA","USA","USA","USA",...,"USA","USA","USA","USA","USA"]]
# ...
