# %%
import polars as pl
import polars_baseline as pb

# %%
df = pl.read_csv('./example_phonebook_data.csv')

# %%
pb.count_by_email_provider(df=df)
# Out:
# shape: (2, 2)
# ┌─────────────────────┬───────┐
# │ email_provider      ┆ count │
# │ ---                 ┆ ---   │
# │ str                 ┆ u32   │
# ╞═════════════════════╪═══════╡
# │ otherdummyemail.com ┆ 25    │
# │ dummyemail.com      ┆ 25    │
# └─────────────────────┴───────┘

# %%
pb.count_by_state(df=df)
# Out:
# shape: (4, 2)
# ┌────────────┬───────┐
# │ state      ┆ count │
# │ ---        ┆ ---   │
# │ str        ┆ u32   │
# ╞════════════╪═══════╡
# │ Florida    ┆ 12    │
# │ New York   ┆ 12    │
# │ California ┆ 13    │
# │ Texas      ┆ 13    │
# └────────────┴───────┘

# %%
df
# Out:
# shape: (50, 6)
# ┌────────────┬───────────┬──────────────┬────────────┬─────────┬─────────────────────────────────┐
# │ first_name ┆ last_name ┆ phone_number ┆ state      ┆ country ┆ email                           │
# │ ---        ┆ ---       ┆ ---          ┆ ---        ┆ ---     ┆ ---                             │
# │ str        ┆ str       ┆ str          ┆ str        ┆ str     ┆ str                             │
# ╞════════════╪═══════════╪══════════════╪════════════╪═════════╪═════════════════════════════════╡
# │ John       ┆ Smith     ┆ 555-0101     ┆ California ┆ USA     ┆ john.smith@dummyemail.com       │
# │ Emma       ┆ Johnson   ┆ 555-0102     ┆ Texas      ┆ USA     ┆ emma.johnson@dummyemail.com     │
# │ Michael    ┆ Williams  ┆ 555-0103     ┆ New York   ┆ USA     ┆ michael.williams@dummyemail.co… │
# │ Sarah      ┆ Brown     ┆ 555-0104     ┆ Florida    ┆ USA     ┆ sarah.brown@dummyemail.com      │
# ...

# %%
df.with_row_index()
# Out:
# shape: (50, 7)
# ┌───────┬────────────┬───────────┬──────────────┬────────────┬─────────┬───────────────────────────┐
# │ index ┆ first_name ┆ last_name ┆ phone_number ┆ state      ┆ country ┆ email                     │
# │ ---   ┆ ---        ┆ ---       ┆ ---          ┆ ---        ┆ ---     ┆ ---                       │
# │ u32   ┆ str        ┆ str       ┆ str          ┆ str        ┆ str     ┆ str                       │
# ╞═══════╪════════════╪═══════════╪══════════════╪════════════╪═════════╪═══════════════════════════╡
# │ 0     ┆ John       ┆ Smith     ┆ 555-0101     ┆ California ┆ USA     ┆ john.smith@dummyemail.com │
# │ 1     ┆ Emma       ┆ Johnson   ┆ 555-0102     ┆ Texas      ┆ USA     ┆ emma.johnson@dummyemail.c │
# │       ┆            ┆           ┆              ┆            ┆         ┆ om                        │
# │ 2     ┆ Michael    ┆ Williams  ┆ 555-0103     ┆ New York   ┆ USA     ┆ michael.williams@dummyema │
# ...
