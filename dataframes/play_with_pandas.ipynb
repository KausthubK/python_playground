# %%
import pandas as pd
import pandas_baseline as pb

# %%
df = pd.read_csv('./example_phonebook_data.csv')

# %%
pb.count_by_email_provider(df=df)
# Out:
#         email_provider  count
# 0       dummyemail.com     25
# 1  otherdummyemail.com     25

# %%
pb.count_by_state(df=df)
# Out:
#         state  count
# 0  California     13
# 1     Florida     12
# 2    New York     12
# 3       Texas     13
