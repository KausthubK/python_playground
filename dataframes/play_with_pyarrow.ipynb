# %%
import pyarrow.csv as csv
import pyarrow_baseline as pb

# %%
df = csv.read_csv('./example_phonebook_data.csv')

# %%
pb.count_by_email_provider(df=df)
# Out:
# pyarrow.Table
# email_provider: string
# count: int64
# ----
# email_provider: [["dummyemail.com","otherdummyemail.com"]]
# count: [[25,25]]

# %%
pb.count_by_state(df=df)
# Out:
# pyarrow.Table
# state: string
# count: int64
# ----
# state: [["California","Texas","New York","Florida"]]
# count: [[13,13,12,12]]
