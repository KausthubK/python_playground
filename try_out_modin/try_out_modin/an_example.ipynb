# %%
import modin.pandas as pd

# %%
pd.DataFrame(data={'col1': [1, 2], 'col2': [3, 4]})
# Out:
# 2023-10-27 11:27:47,978	INFO util.py:159 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/kausthub.k/Development/datascience/python_playground/try_out_modin/try_out_modin/an_example.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/kausthub.k/Development/datascience/python_playground/try_out_modin/try_out_modin/an_example.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> pd.DataFrame(data={'col1': [1, 2], 'col2': [3, 4]})
#
# File ~/Library/Caches/pypoetry/virtualenvs/try-out-modin-HNV82WXI-py3.10/lib/python3.10/site-packages/modin/logging/logger_decorator.py:129, in enable_logging.<locals>.decorator.<locals>.run_and_log(*args, **kwargs)
#     114 """
#     115 Compute function with logging if Modin logging is enabled.
#     116
#    (...)
# ...
